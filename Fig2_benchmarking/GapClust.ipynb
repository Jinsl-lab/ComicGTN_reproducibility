# %%
library(Matrix)
library(Seurat)
library(GapClust)
data <- readMM("./ComicGTN/data/BMMC-bench-1/Gene_Cell.mtx")
Cell_names <- read.table("./ComicGTN/data/BMMC-bench-1/Cell_names.tsv", header = FALSE)
Gene_names <- read.table("./ComicGTN/data/BMMC-bench-1/Gene_names.tsv", header = FALSE)
data <- as.matrix(data)
rownames(data) <- Gene_names[,1]
colnames(data) <- Cell_names[,1]
results <- GapClust(data,k=200)
# Out:
# Attaching SeuratObject
#
# Warning message in asMethod(object):
# “sparse->dense coercion: allocating vector of size 3.4 GiB”

# %%
my_list <- results$rare_cell_indice

# %%
library(tidyverse)
df_long <- my_list %>% 
  enframe(name = "index", value = "values") %>%
  unnest(values)
df_long$values <- df_long$values - 1
# Out:
# ── Attaching packages ───────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse 1.3.2 ──
# ✔ ggplot2 3.5.1     ✔ purrr   1.0.2
# ✔ tibble  3.2.1     ✔ dplyr   1.1.4
# ✔ tidyr   1.3.1     ✔ stringr 1.5.1
# ✔ readr   2.1.5     ✔ forcats 1.0.0
# ── Conflicts ──────────────────────────────────────────────────────────────────────────────────────────────────────────────────────── tidyverse_conflicts() ──
# ✖ tidyr::expand() masks Matrix::expand()
# ✖ dplyr::filter() masks stats::filter()
# ✖ dplyr::lag()    masks stats::lag()
# ✖ tidyr::pack()   masks Matrix::pack()
# ✖ tidyr::unpack() masks Matrix::unpack()

# %%
write.table(df_long, "./ComicGTN/data/BMMC-bench-1/GapClust_output.tsv", sep = "\t", row.names = FALSE)
